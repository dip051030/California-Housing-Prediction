# %%
import pandas as pd, numpy as np, matplotlib.pyplot as plt, seaborn as sns

# %%
df = pd.read_csv(filepath_or_buffer=r'housing.csv')

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                41.0        880.0           129.0
# 1    -122.22     37.86                21.0       7099.0          1106.0
# 2    -122.24     37.85                52.0       1467.0           190.0
# 3    -122.25     37.85                52.0       1274.0           235.0
# 4    -122.25     37.85                52.0       1627.0           280.0
#
#    population  households  median_income  median_house_value ocean_proximity
# 0       322.0       126.0         8.3252            452600.0        NEAR BAY
# 1      2401.0      1138.0         8.3014            358500.0        NEAR BAY
# 2       496.0       177.0         7.2574            352100.0        NEAR BAY
# 3       558.0       219.0         5.6431            341300.0        NEAR BAY
# 4       565.0       259.0         3.8462            342200.0        NEAR BAY

# %%
df.shape
# Out:
# (20640, 10)

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
# ...

# %%
df.size
# Out:
# 206400

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.isna().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# median_house_value      0
# ocean_proximity         0
# dtype: int64

# %%
df['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df = df.dropna(axis = 0)

# %%
df.shape
# Out:
# (20433, 10)

# %%
df.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# ocean_proximity       0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20433 non-null  float64
#  1   latitude            20433 non-null  float64
#  2   housing_median_age  20433 non-null  float64
#  3   total_rooms         20433 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20433 non-null  float64
#  6   households          20433 non-null  float64
#  7   median_income       20433 non-null  float64
#  8   median_house_value  20433 non-null  float64
#  9   ocean_proximity     20433 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.7+ MB

# %%
X_features = df.drop(columns=['median_house_value'])
y_target = df['median_house_value']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_features, y_target, test_size=0.25)

# %%
trained_data = X_train.join(y_train)

# %%
trained_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11057    -117.86     33.79                34.0       1883.0           408.0
# 16593    -121.42     37.73                 2.0       2682.0           393.0
# 2782     -114.66     32.74                17.0       1388.0           386.0
# 17174    -122.46     37.51                23.0        949.0           151.0
# 7595     -118.25     33.90                38.0       1201.0           223.0
# ...          ...       ...                 ...          ...             ...
# 19678    -121.62     39.16                16.0       2037.0           464.0
# 12632    -121.48     38.49                26.0       3165.0           806.0
# 2823     -119.08     35.42                10.0       4159.0           608.0
# 7504     -118.27     33.92                35.0       1818.0           374.0
# 19457    -120.93     37.67                 6.0       3491.0           657.0
#
# ...

# %%
trained_data.hist(figsize=(15, 10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(trained_data.corr(numeric_only=True), annot=True, cmap='viridis', linecolor='black', linewidths=0.5)
# Out:
# <Axes: >

# %%
trained_data['total_rooms'] = np.log(trained_data['total_rooms'] + 1)
trained_data['total_bedrooms'] = np.log(trained_data['total_bedrooms'] + 1)
trained_data['population'] = np.log(trained_data['population'] + 1)
trained_data['households'] = np.log(trained_data['households'] + 1)

# %%
trained_data.hist(figsize=(15, 8))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'households'}>,
#         <Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>]], dtype=object)

# %%
trained_data['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     6770
# INLAND        4902
# NEAR OCEAN    1943
# NEAR BAY      1705
# ISLAND           4
# Name: count, dtype: int64

# %%
trained_data = trained_data.join(pd.get_dummies(trained_data['ocean_proximity']) * 1).drop(['ocean_proximity'], axis = 1)

# %%
trained_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11057    -117.86     33.79                34.0     7.541152        6.013715
# 16593    -121.42     37.73                 2.0     7.894691        5.976351
# 2782     -114.66     32.74                17.0     7.236339        5.958425
# 17174    -122.46     37.51                23.0     6.856462        5.023881
# 7595     -118.25     33.90                38.0     7.091742        5.411646
# ...          ...       ...                 ...          ...             ...
# 19678    -121.62     39.16                16.0     7.619724        6.142037
# 12632    -121.48     38.49                26.0     8.060224        6.693324
# 2823     -119.08     35.42                10.0     8.333270        6.411818
# 7504     -118.27     33.92                35.0     7.506042        5.926926
# 19457    -120.93     37.67                 6.0     8.158230        6.489205
#
# ...

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(trained_data.corr(), annot=True, cmap='viridis', linecolor='black', linewidths=0.5)
# Out:
# <Axes: >

# %%
trained_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15324 entries, 11057 to 19457
# Data columns (total 14 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           15324 non-null  float64
#  1   latitude            15324 non-null  float64
#  2   housing_median_age  15324 non-null  float64
#  3   total_rooms         15324 non-null  float64
#  4   total_bedrooms      15324 non-null  float64
#  5   population          15324 non-null  float64
#  6   households          15324 non-null  float64
#  7   median_income       15324 non-null  float64
#  8   median_house_value  15324 non-null  float64
#  9   <1H OCEAN           15324 non-null  int64
#  10  INLAND              15324 non-null  int64
#  11  ISLAND              15324 non-null  int64
#  12  NEAR BAY            15324 non-null  int64
#  13  NEAR OCEAN          15324 non-null  int64
# dtypes: float64(9), int64(5)
# memory usage: 2.3 MB

# %%
plt.figure(figsize=(14, 10))
sns.scatterplot(x='latitude', y ='longitude', data = trained_data, hue = 'median_house_value', palette='coolwarm')
# Out:
# <Axes: xlabel='latitude', ylabel='longitude'>

# %%
trained_data['bedroom_ratio'] = trained_data['total_bedrooms'] / trained_data['total_rooms']
trained_data['households_rooms'] = trained_data['total_rooms'] / trained_data['households']

# %%
trained_data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11057    -117.86     33.79                34.0     7.541152        6.013715
# 16593    -121.42     37.73                 2.0     7.894691        5.976351
# 2782     -114.66     32.74                17.0     7.236339        5.958425
# 17174    -122.46     37.51                23.0     6.856462        5.023881
# 7595     -118.25     33.90                38.0     7.091742        5.411646
# ...          ...       ...                 ...          ...             ...
# 19678    -121.62     39.16                16.0     7.619724        6.142037
# 12632    -121.48     38.49                26.0     8.060224        6.693324
# 2823     -119.08     35.42                10.0     8.333270        6.411818
# 7504     -118.27     33.92                35.0     7.506042        5.926926
# 19457    -120.93     37.67                 6.0     8.158230        6.489205
#
# ...

# %%
plt.figure(figsize=(14, 12))
sns.heatmap(trained_data.corr(), annot=True, linecolor='black', linewidths=0.5, cmap='viridis')
# Out:
# <Axes: >

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
trained_data = trained_data.dropna(axis = 0)
X_train, y_train = trained_data.drop(['median_house_value'], axis = 1), trained_data['median_house_value']

X_train_s = scaler.fit_transform(X_train)

reg = LinearRegression()
reg.fit(X_train_s, y_train)
# Out:
# LinearRegression()

# %%
X_train.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# <1H OCEAN             0
# INLAND                0
# ISLAND                0
# NEAR BAY              0
# NEAR OCEAN            0
# bedroom_ratio         0
# households_rooms      0
# dtype: int64

# %%
X_train.shape
# Out:
# (15324, 15)

# %%
reg.score(X_train, y_train)
# Out:
# /home/dip__4/anaconda3/envs/myenv/lib/python3.10/site-packages/sklearn/utils/validation.py:2732: UserWarning: X has feature names, but LinearRegression was fitted without feature names
#   warnings.warn(
# -2086.366035155092

# %%
test_data = X_test.join(y_test)

test_data['total_rooms'] = np.log(test_data['total_rooms'] + 1)
test_data['total_bedrooms'] = np.log(test_data['total_bedrooms'] + 1)
test_data['population'] = np.log(test_data['population'] + 1)
test_data['households'] = np.log(test_data['households'] + 1)

test_data = test_data.join(pd.get_dummies(test_data['ocean_proximity']) * 1).drop(['ocean_proximity'], axis = 1)

test_data['bedroom_ratio'] = test_data['total_bedrooms'] / test_data['total_rooms']
test_data['households_rooms'] = test_data['total_rooms'] / test_data['households']

X_test, y_test = test_data.drop(['median_house_value'], axis = 1), test_data['median_house_value']

# %%
test_data.isna().sum()
# Out:
# longitude             0
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# <1H OCEAN             0
# INLAND                0
# ISLAND                0
# NEAR BAY              0
# NEAR OCEAN            0
# bedroom_ratio         0
# households_rooms      0
# dtype: int64

# %%
test_data.shape
# Out:
# (5109, 16)

# %%
trained_data.shape
# Out:
# (15324, 16)

# %%
trained_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 15324 entries, 11057 to 19457
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           15324 non-null  float64
#  1   latitude            15324 non-null  float64
#  2   housing_median_age  15324 non-null  float64
#  3   total_rooms         15324 non-null  float64
#  4   total_bedrooms      15324 non-null  float64
#  5   population          15324 non-null  float64
#  6   households          15324 non-null  float64
#  7   median_income       15324 non-null  float64
#  8   median_house_value  15324 non-null  float64
#  9   <1H OCEAN           15324 non-null  int64
#  10  INLAND              15324 non-null  int64
#  11  ISLAND              15324 non-null  int64
#  12  NEAR BAY            15324 non-null  int64
#  13  NEAR OCEAN          15324 non-null  int64
#  14  bedroom_ratio       15324 non-null  float64
# ...

# %%
X_test.shape
# Out:
# (5109, 15)

# %%
y_test.shape
# Out:
# (5109,)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5109 entries, 11176 to 10146
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           5109 non-null   float64
#  1   latitude            5109 non-null   float64
#  2   housing_median_age  5109 non-null   float64
#  3   total_rooms         5109 non-null   float64
#  4   total_bedrooms      5109 non-null   float64
#  5   population          5109 non-null   float64
#  6   households          5109 non-null   float64
#  7   median_income       5109 non-null   float64
#  8   <1H OCEAN           5109 non-null   int64
#  9   INLAND              5109 non-null   int64
#  10  ISLAND              5109 non-null   int64
#  11  NEAR BAY            5109 non-null   int64
#  12  NEAR OCEAN          5109 non-null   int64
#  13  bedroom_ratio       5109 non-null   float64
#  14  households_rooms    5109 non-null   float64
# dtypes: float64(10), int64(5)
# ...

# %%
y_test.info()
# Out:
# <class 'pandas.core.series.Series'>
# Index: 5109 entries, 11176 to 10146
# Series name: median_house_value
# Non-Null Count  Dtype
# --------------  -----
# 5109 non-null   float64
# dtypes: float64(1)
# memory usage: 208.9 KB

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11057    -117.86     33.79                34.0     7.541152        6.013715
# 16593    -121.42     37.73                 2.0     7.894691        5.976351
# 2782     -114.66     32.74                17.0     7.236339        5.958425
# 17174    -122.46     37.51                23.0     6.856462        5.023881
# 7595     -118.25     33.90                38.0     7.091742        5.411646
# ...          ...       ...                 ...          ...             ...
# 19678    -121.62     39.16                16.0     7.619724        6.142037
# 12632    -121.48     38.49                26.0     8.060224        6.693324
# 2823     -119.08     35.42                10.0     8.333270        6.411818
# 7504     -118.27     33.92                35.0     7.506042        5.926926
# 19457    -120.93     37.67                 6.0     8.158230        6.489205
#
# ...

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 11176    -117.96     33.83                30.0     7.951207        6.476972
# 10437    -117.62     33.42                27.0     6.913737        5.587249
# 1170     -121.58     39.51                24.0     7.531552        5.921578
# 5760     -118.29     34.17                52.0     7.457609        5.723585
# 13798    -117.41     34.58                10.0     7.994632        6.505784
# ...          ...       ...                 ...          ...             ...
# 5456     -118.47     34.00                38.0     7.119636        5.968708
# 720      -122.10     37.68                37.0     7.657755        6.222576
# 1317     -121.80     37.99                16.0     8.032035        6.144186
# 15352    -117.31     33.25                14.0     8.155936        6.639876
# 10146    -117.92     33.92                19.0     7.687997        5.993961
#
# ...

# %%
X_test_s = scaler.transform(X_test)

# %%
reg.score(X_test_s, y_test)
# Out:
# 0.6623067727494605

# %%
from sklearn.ensemble import RandomForestRegressor

forest = RandomForestRegressor()

forest.fit(X_train_s, y_train)

forest.score(X_test_s, y_test)
# Out:
# 0.8096656842862876

# %%
forest.score(X_test_s, y_test)
# Out:
# 0.8096656842862876

# %%
from sklearn.model_selection import GridSearchCV
forest = RandomForestRegressor()

param_grid = {
    'n_estimators': [100, 200, 300],
    # 'max_features': [8, 12, 20],
    'min_samples_split': [2, 4],
    'max_depth': [None, 4, 8]
}

grid_search = GridSearchCV(forest, param_grid, cv = 5, scoring = 'neg_mean_squared_error', return_train_score=True)
grid_search.fit(X_train_s, y_train)
# Out:
# GridSearchCV(cv=5, estimator=RandomForestRegressor(),
#              param_grid={'max_depth': [None, 4, 8], 'min_samples_split': [2, 4],
#                          'n_estimators': [100, 200, 300]},
#              return_train_score=True, scoring='neg_mean_squared_error')

# %%
best_forest = grid_search.best_estimator_

# %%
best_forest.score(X_test_s, y_test)
# Out:
# 0.8121092918489579

# %%
plt.figure(figsize=(10,6))
plt.plot(range(1,11), y_test[:10], 'o-', label='Actual')
plt.plot(range(1,11), rf.predict(X_test_s)[:10], 'x-', label='Predicted')
plt.xlabel('Sample Number')
plt.ylabel('Target Value')
plt.title('Actual vs Predicted (first 10 samples)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 plt.figure(figsize=(10,6))
#       2 plt.plot(range(1,11), y_test[:10], 'o-', label='Actual')
# ----> 3 plt.plot(range(1,11), rf.predict(X_test_s)[:10], 'x-', label='Predicted')
#       4 plt.xlabel('Sample Number')
#       5 plt.ylabel('Target Value')
#
# NameError: name 'rf' is not defined
